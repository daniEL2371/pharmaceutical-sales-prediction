# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join('../scripts')))
from IPython.display import Markdown, display, Image
import warnings
warnings.filterwarnings('ignore')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import numpy as np
from statsmodels.tsa.stattools import adfuller, acf, pacf
import pandas as pd
from sklearn.preprocessing import Normalizer, MinMaxScaler, StandardScaler, RobustScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import datetime
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
sns.set()

# %%
from helper import Helper
import plots

# %%
helper = Helper()

# %%
train = helper.read_csv("../data/train.csv")
test = helper.read_csv("../data/test.csv")
# Out:
# file read as csv
# file read as csv

# %%
display(train.head())
display(train.describe())
display(train.info())
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#               Store     DayOfWeek         Sales     Customers          Open  \
# count  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06  1.017209e+06
# mean   5.584297e+02  3.998341e+00  5.773819e+03  6.331459e+02  8.301067e-01
# std    3.219087e+02  1.997391e+00  3.849926e+03  4.644117e+02  3.755392e-01
# min    1.000000e+00  1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.800000e+02  2.000000e+00  3.727000e+03  4.050000e+02  1.000000e+00
# 50%    5.580000e+02  4.000000e+00  5.744000e+03  6.090000e+02  1.000000e+00
# 75%    8.380000e+02  6.000000e+00  7.856000e+03  8.370000e+02  1.000000e+00
# max    1.115000e+03  7.000000e+00  4.155100e+04  7.388000e+03  1.000000e+00
#
#               Promo  SchoolHoliday
# count  1.017209e+06   1.017209e+06
# mean   3.815145e-01   1.786467e-01
# std    4.857586e-01   3.830564e-01
# min    0.000000e+00   0.000000e+00
# 25%    0.000000e+00   0.000000e+00
# 50%    0.000000e+00   0.000000e+00
# 75%    1.000000e+00   0.000000e+00
# max    1.000000e+00   1.000000e+00
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB
# None

# %%
helper.percent_missing(train)
# Out:
# 0.0

# %%
def get_feature(df):
    return df[["Date", "Sales"]]

# %%
def drop_closed(df):
    df = df[df['Open'] == 1]
    return df

# %%
def scaler(df, columns, mode="minmax"):
    if (mode == "minmax"):
        minmax_scaler = MinMaxScaler()
        return pd.DataFrame(minmax_scaler.fit_transform(df), columns=columns), minmax_scaler
    elif (mode == "standard"):
        scaler = StandardScaler()
        return pd.DataFrame(scaler.fit_transform(df), columns=columns), scaler
    elif (mode == "robust"):
        scaler = RobustScaler()
        return pd.DataFrame(scaler.fit_transform(df), columns=columns), scaler

# %%
def add_scaled_sales(df):
    scaled_sales, scaler_obj = scaler(df[["Sales"]], mode="minmax", columns=["scaled_sales"])
    df["scaled_sales"] = scaled_sales["scaled_sales"].to_list()
    return df, scaler_obj

# %%
def handle_outliers(df, col, method="lower_upper"):
        
        df = df.copy()
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)

        lower_bound = q1 - ((1.5) * (q3 - q1))
        upper_bound = q3 + ((1.5) * (q3 - q1))

        if method == "mean":
            df[col] = np.where(df[col] < lower_bound,   df[col].mean(), df[col])
            df[col] = np.where(df[col] > upper_bound, df[col].mean(), df[col])

        elif  method == "mode":
            df[col] = np.where(df[col] < lower_bound,   df[col].mode()[0], df[col])
            df[col] = np.where(df[col] > upper_bound, df[col].mode()[0], df[col])
        else:
            df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
            df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

        return df

# %%
train["Sales"] = train["Sales"].astype("float")

# %%
data = drop_closed(train)
data = get_feature(data)
data = handle_outliers(data, "Sales")

# %%
data_agg = data.groupby("Date").agg({"Sales": "mean"})
helper.percent_missing(data_agg)
data_agg.describe()
# Out:
#               Sales
# count    942.000000
# mean    6988.142162
# std     1475.510458
# min     4057.782960
# 25%     5725.756766
# 50%     6822.535825
# 75%     7778.867102
# max    11908.661883

# %%
def check_stationary(df, col):
    adfResult = adfuller(df[col].values, autolag='AIC')
    print(f'ADF Statistic: {adfResult[0]}')
    print(f'p-value: {adfResult[1]}')
    return adfResult[1] >= 0.05

# %%
check_stationary(data_agg, "Sales")
# Out:
# ADF Statistic: -4.7192713993360185
# p-value: 7.741088433521508e-05
# False

# %%
def difference(dataset, interval=1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i] - dataset[i - interval]
        diff.append(value)
    return pd.Series(diff)

# %%
def corrPlots(array: np.array, is_partial=False):
    plt.figure(figsize=(30, 5))
#     plt.title(title)
#     plt.bar(range(len(array)), array)
#     plt.grid(True)
    if (not is_partial):
        plot_acf(array)
    else:
        plot_pacf(array)
    plt.show()

# %%
acfSalesScaled = acf(data_agg["Sales"].values, fft=True, nlags=40)
acfSalesScaledNp = np.array(acfSalesScaled)
corrPlots(acfSalesScaledNp)

# %%
pacfSalesScaled = pacf(data_agg["Sales"].values, nlags=40)
pacfSalesScaledNp = np.array(pacfSalesScaled)
corrPlots(pacfSalesScaledNp, is_partial=True)

# %%
scaled_df, scaler_obj = add_scaled_sales(data_agg)
data_agg["Sales"].isna().any().sum()
# Out:
# 0

# %%
import mlflow.tensorflow

class TimeSeriesSalsesPred:
    
    def __init__(self, WINDOW_SIZE, BATCH_SIZE, sales_data):
        self.WINDOW_SIZE = WINDOW_SIZE
        self.BATCH_SIZE = BATCH_SIZE
        
        data_agg = sales_data.groupby("Date").agg({"Sales": "mean"})
        self.SIZE = len(data_agg["Sales"])

        self.scaled_df, self.scaler_obj = add_scaled_sales(data_agg)
        
        self.DateTrain = np.reshape(self.scaled_df.index.values[0:BATCH_SIZE], (-1, 1))
        self.DateValid = np.reshape(self.scaled_df.index.values[BATCH_SIZE:], (-1, 1))
        
        self.train_sales, self.valid_sales, self.TrainDataset, self.ValidDataset = self.prepare_data(WINDOW_SIZE,
                                                                                                     BATCH_SIZE, 
                                                                                                     self.scaled_df)
    
    def prepare_data(self, WINDOW_SIZE, BATCH_SIZE, scaled_df):
        train_sales = scaled_df["scaled_sales"].values[0:BATCH_SIZE].astype('float32')
        valid_sales = scaled_df["scaled_sales"].values[BATCH_SIZE:].astype('float32')
        TrainDataset = self.windowed_dataset(train_sales, WINDOW_SIZE, BATCH_SIZE)
        ValidDataset = self.windowed_dataset(valid_sales, WINDOW_SIZE, BATCH_SIZE)
        
        return train_sales, valid_sales, TrainDataset, ValidDataset
    
    def train(self, EPOCHS, verbose=1, ):
        
        mlflow.set_experiment('Rossman-' + 'Lstm_model')

        mlflow.tensorflow.autolog(every_n_iter=2,log_models=True)

        mlflow.end_run()
        with mlflow.start_run(run_name="Lstm_model-Base-line"):

            model = Sequential()
            model.add(LSTM(20, input_shape=[None, 1], return_sequences=True))
            model.add(LSTM(10, input_shape=[None, 1]))
            model.add(Dense(1))
            model.compile(loss="huber_loss", optimizer='adam')
            model.summary()

            history = model.fit(self.TrainDataset, epochs=EPOCHS, validation_data=self.ValidDataset, verbose=verbose)
        
        self.plot_history(history)
        
        
        return model, history
    
    def plot_history(self, history):
        fig = plt.figure(figsize=(12, 9))
        plt.plot(history.history['loss'], label="loss")
        plt.plot(history.history['val_loss'], label="val_loss")
        plt.legend()
        plt.show()
        
        return fig
    
   
    def model_forecast_test(self, model):

        series = self.scaled_df["scaled_sales"].values[:, np.newaxis]

        ds = tf.data.Dataset.from_tensor_slices(series)
        ds = ds.window(self.WINDOW_SIZE, shift=1, drop_remainder=True) 
        ds = ds.flat_map(lambda w: w.batch(self.WINDOW_SIZE))
        ds = ds.batch(self.SIZE).prefetch(1)
        forecast = model.predict(ds)
        
        Results = forecast[self.BATCH_SIZE-self.WINDOW_SIZE:-1]
        Results1 = self.scaler_obj.inverse_transform(Results.reshape(-1,1))
        XValid1 = self.scaler_obj.inverse_transform(self.valid_sales.reshape(-1,1))
        
        fig, MAE, RMSE = self.plot_forcast(Results, Results1, XValid1, self.DateValid, self.WINDOW_SIZE)
        
        
        return forecast, fig, MAE, RMSE
    
    def plot_forcast(self, Results, Results1, XValid1, DateValid,  WINDOW_SIZE):
        fig = plt.figure(figsize=(30, 8))
        plt.title("LSTM Model Forecast Compared to Validation Data")
        
        plt.plot(DateValid.astype('datetime64'), Results1, label='Forecast series')
        plt.plot(DateValid.astype('datetime64'), np.reshape(XValid1, (2*WINDOW_SIZE, 1)), label='Validation series')
        
        plt.xlabel('Date')
        plt.ylabel('Thousands of Units')
        plt.xticks(DateValid.astype('datetime64')[:,-1], rotation = 90) 
        plt.legend(loc="upper right")

        MAE = tf.keras.metrics.mean_absolute_error(XValid1[:,-1], Results[:,-1]).numpy()
        RMSE = np.sqrt(tf.keras.metrics.mean_squared_error(XValid1[:,-1], Results[:,-1]).numpy())

        textstr = "MAE = " + "{:.3f}".format(MAE) + "  RMSE = " + "{:.3f}".format(RMSE)

        # place a text box in upper left in axes coords
        plt.annotate(textstr, xy=(0.87, 0.05), xycoords='axes fraction')
        plt.grid(True)

        plt.show()
        
        return fig, MAE, RMSE
    
        
        

    
    def windowed_dataset(self, series, window_size, batch_size): 
        series = tf.expand_dims(series, axis=-1)
        dataset = tf.data.Dataset.from_tensor_slices(series)
        dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True) 
        dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
        dataset = dataset.map(lambda window: (window[:-1], window[-1:]))
        dataset = dataset.batch(batch_size).prefetch(1)
        return dataset

# %%
SIZE = len(data_agg["Sales"])
WINDOW_SIZE = 49
BATCH_SIZE= SIZE-WINDOW_SIZE*2
EPOCHS = 200

t = TimeSeriesSalsesPred(WINDOW_SIZE, BATCH_SIZE, data)

# %%
model1, his = t.train(EPOCHS)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, None, 20)          1760
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 10)                1240
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 3,011
# Trainable params: 3,011
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 1/1 [==============================] 0.121 - 10s 10s/step - loss: 0.1210 - val_loss: 0.1059
# Epoch 2/200
# 1/1 [==============================] - ETA: 0s - loss: 0.107 - 2s 2s/step - loss: 0.1073 - val_loss: 0.0936
# Epoch 3/200
# 1/1 [==============================] - ETA: 0s - loss: 0.095 - 0s 331ms/step - loss: 0.0950 - val_loss: 0.0824
# Epoch 4/200
# 1/1 [==============================] - ETA: 0s - loss: 0.083 - 0s 355ms/step - loss: 0.0839 - val_loss: 0.0723
# Epoch 5/200
# 1/1 [==============================] - ETA: 0s - loss: 0.073 - 1s 640ms/step - loss: 0.0739 - val_loss: 0.0632
# Epoch 6/200
# 1/1 [==============================] - ETA: 0s - loss: 0.064 - 0s 421ms/step - loss: 0.0649 - val_loss: 0.0549
# Epoch 7/200
# 1/1 [==============================] - ETA: 0s - loss: 0.056 - 0s 430ms/step - loss: 0.0567 - val_loss: 0.0474
# Epoch 8/200
# 1/1 [==============================] - ETA: 0s - loss: 0.049 - 0s 391ms/step - loss: 0.0493 - val_loss: 0.0407
# Epoch 9/200
# 1/1 [==============================] - ETA: 0s - loss: 0.042 - 0s 463ms/step - loss: 0.0427 - val_loss: 0.0347
# Epoch 10/200
# 1/1 [==============================] - ETA: 0s - loss: 0.036 - 0s 381ms/step - loss: 0.0368 - val_loss: 0.0294
# Epoch 11/200
# 1/1 [==============================] - ETA: 0s - loss: 0.031 - 0s 409ms/step - loss: 0.0317 - val_loss: 0.0248
# Epoch 12/200
# 1/1 [==============================] - ETA: 0s - loss: 0.027 - 0s 474ms/step - loss: 0.0273 - val_loss: 0.0211
# Epoch 13/200
# 1/1 [==============================] - ETA: 0s - loss: 0.023 - 0s 446ms/step - loss: 0.0238 - val_loss: 0.0182
# Epoch 14/200
# 1/1 [==============================] - ETA: 0s - loss: 0.021 - 0s 482ms/step - loss: 0.0210 - val_loss: 0.0161
# Epoch 15/200
# 1/1 [==============================] - ETA: 0s - loss: 0.019 - 1s 630ms/step - loss: 0.0192 - val_loss: 0.0150
# Epoch 16/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 531ms/step - loss: 0.0183 - val_loss: 0.0147
# Epoch 17/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 519ms/step - loss: 0.0182 - val_loss: 0.0151
# Epoch 18/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 416ms/step - loss: 0.0188 - val_loss: 0.0161
# Epoch 19/200
# 1/1 [==============================] - ETA: 0s - loss: 0.019 - 0s 476ms/step - loss: 0.0199 - val_loss: 0.0171
# Epoch 20/200
# 1/1 [==============================] - ETA: 0s - loss: 0.021 - 1s 610ms/step - loss: 0.0210 - val_loss: 0.0180
# Epoch 21/200
# 1/1 [==============================] - ETA: 0s - loss: 0.021 - 0s 412ms/step - loss: 0.0219 - val_loss: 0.0184
# Epoch 22/200
# 1/1 [==============================] - ETA: 0s - loss: 0.022 - 0s 486ms/step - loss: 0.0225 - val_loss: 0.0185
# Epoch 23/200
# 1/1 [==============================] - ETA: 0s - loss: 0.022 - 1s 630ms/step - loss: 0.0225 - val_loss: 0.0182
# Epoch 24/200
# 1/1 [==============================] - ETA: 0s - loss: 0.022 - 0s 395ms/step - loss: 0.0222 - val_loss: 0.0176
# Epoch 25/200
# 1/1 [==============================] - ETA: 0s - loss: 0.021 - 0s 426ms/step - loss: 0.0216 - val_loss: 0.0170
# Epoch 26/200
# 1/1 [==============================] - ETA: 0s - loss: 0.020 - 0s 362ms/step - loss: 0.0209 - val_loss: 0.0163
# Epoch 27/200
# 1/1 [==============================] - ETA: 0s - loss: 0.020 - 0s 288ms/step - loss: 0.0202 - val_loss: 0.0158
# Epoch 28/200
# 1/1 [==============================] - ETA: 0s - loss: 0.019 - 0s 279ms/step - loss: 0.0195 - val_loss: 0.0153
# Epoch 29/200
# 1/1 [==============================] - ETA: 0s - loss: 0.019 - 0s 281ms/step - loss: 0.0190 - val_loss: 0.0150
# Epoch 30/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 320ms/step - loss: 0.0186 - val_loss: 0.0148
# Epoch 31/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 502ms/step - loss: 0.0183 - val_loss: 0.0148
# Epoch 32/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 606ms/step - loss: 0.0182 - val_loss: 0.0149
# Epoch 33/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 391ms/step - loss: 0.0182 - val_loss: 0.0150
# Epoch 34/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 439ms/step - loss: 0.0182 - val_loss: 0.0151
# Epoch 35/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 466ms/step - loss: 0.0183 - val_loss: 0.0153
# Epoch 36/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 371ms/step - loss: 0.0184 - val_loss: 0.0154
# Epoch 37/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 406ms/step - loss: 0.0185 - val_loss: 0.0156
# Epoch 38/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 392ms/step - loss: 0.0186 - val_loss: 0.0157
# Epoch 39/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 505ms/step - loss: 0.0187 - val_loss: 0.0157
# Epoch 40/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 452ms/step - loss: 0.0187 - val_loss: 0.0157
# Epoch 41/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 425ms/step - loss: 0.0188 - val_loss: 0.0157
# Epoch 42/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 557ms/step - loss: 0.0187 - val_loss: 0.0157
# Epoch 43/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 418ms/step - loss: 0.0187 - val_loss: 0.0156
# Epoch 44/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 304ms/step - loss: 0.0186 - val_loss: 0.0155
# Epoch 45/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 342ms/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 46/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 355ms/step - loss: 0.0185 - val_loss: 0.0153
# Epoch 47/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 375ms/step - loss: 0.0184 - val_loss: 0.0152
# Epoch 48/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 286ms/step - loss: 0.0183 - val_loss: 0.0151
# Epoch 49/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 283ms/step - loss: 0.0183 - val_loss: 0.0150
# Epoch 50/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 587ms/step - loss: 0.0182 - val_loss: 0.0149
# Epoch 51/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 600ms/step - loss: 0.0182 - val_loss: 0.0149
# Epoch 52/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 459ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 53/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 370ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 54/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 342ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 55/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 366ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 56/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 311ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 57/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 420ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 58/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 288ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 59/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 316ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 60/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 296ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 61/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 296ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 62/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 304ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 63/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 396ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 64/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 282ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 65/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 324ms/step - loss: 0.0182 - val_loss: 0.0148
# Epoch 66/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 513ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 67/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 436ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 68/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 399ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 69/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 522ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 70/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 337ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 71/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 345ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 72/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 297ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 73/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 319ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 74/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 293ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 75/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 354ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 76/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 299ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 77/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 340ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 78/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 299ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 79/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 290ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 80/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 257ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 81/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 265ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 82/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 281ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 83/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 365ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 84/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 451ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 85/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 388ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 86/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 514ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 87/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 397ms/step - loss: 0.0181 - val_loss: 0.0148
# Epoch 88/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 402ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 89/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 376ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 90/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 331ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 91/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 327ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 92/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 313ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 93/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 293ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 94/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 340ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 95/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 337ms/step - loss: 0.0181 - val_loss: 0.0147
# Epoch 96/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 329ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 97/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 292ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 98/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 339ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 99/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 463ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 100/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 338ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 101/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 342ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 102/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 1s 602ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 103/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 325ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 104/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 316ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 105/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 312ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 106/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 293ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 107/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 286ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 108/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 290ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 109/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 283ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 110/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 288ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 111/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 295ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 112/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 325ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 113/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 347ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 114/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 412ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 115/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 339ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 116/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 398ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 117/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 308ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 118/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 275ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 119/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 301ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 120/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 307ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 121/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 304ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 122/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 287ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 123/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 317ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 124/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 326ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 125/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 350ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 126/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 337ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 127/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 437ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 128/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 323ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 129/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 322ms/step - loss: 0.0180 - val_loss: 0.0147
# Epoch 130/200
# 1/1 [==============================] - ETA: 0s - loss: 0.018 - 0s 310ms/step - loss: 0.0180 - val_loss: 0.0146
# Epoch 131/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 276ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 132/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 278ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 133/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 290ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 134/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 309ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 135/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 345ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 136/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 1s 559ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 137/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 298ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 138/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 458ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 139/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 289ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 140/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 304ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 141/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 336ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 142/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 425ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 143/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 1s 527ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 144/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 300ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 145/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 1s 616ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 146/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 1s 829ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 147/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 389ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 148/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 385ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 149/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 397ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 150/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 388ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 151/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 370ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 152/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 398ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 153/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 1s 562ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 154/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 451ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 155/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 425ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 156/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 314ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 157/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 342ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 158/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 313ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 159/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 308ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 160/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 299ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 161/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 301ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 162/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 326ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 163/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 304ms/step - loss: 0.0179 - val_loss: 0.0146
# Epoch 164/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 331ms/step - loss: 0.0178 - val_loss: 0.0146
# Epoch 165/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 309ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 166/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 319ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 167/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 450ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 168/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 317ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 169/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 305ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 170/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 334ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 171/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 297ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 172/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 299ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 173/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 303ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 174/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 319ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 175/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 313ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 176/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 378ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 177/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 353ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 178/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 320ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 179/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 388ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 180/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 313ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 181/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 323ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 182/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 384ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 183/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 316ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 184/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 314ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 185/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 318ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 186/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 324ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 187/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 306ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 188/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 310ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 189/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 315ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 190/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 303ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 191/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 341ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 192/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 339ms/step - loss: 0.0178 - val_loss: 0.0145
# Epoch 193/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 397ms/step - loss: 0.0177 - val_loss: 0.0145
# Epoch 194/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 300ms/step - loss: 0.0177 - val_loss: 0.0145
# Epoch 195/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 306ms/step - loss: 0.0177 - val_loss: 0.0145
# Epoch 196/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 301ms/step - loss: 0.0177 - val_loss: 0.0145
# Epoch 197/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 338ms/step - loss: 0.0177 - val_loss: 0.0144
# Epoch 198/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 301ms/step - loss: 0.0177 - val_loss: 0.0144
# Epoch 199/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 289ms/step - loss: 0.0177 - val_loss: 0.0144
# Epoch 200/200
# 1/1 [==============================] - ETA: 0s - loss: 0.017 - 0s 295ms/step - loss: 0.0177 - val_loss: 0.0144

# %%
forecast, fig, MAE, RMSE = t.model_forecast_test(model1)

# %%
def forcast_next_one_sale(model, sales):
    data_feat = None
    WINDOW_SIZE = 49
    try:
        data_feat = sales[["Sales", "Date"]]
        
        if (data_feat.shape[0] < 49):
            print("To make prediction, we need atleast data of 49 dates")
            return
        scaled_df, scaler_obj = add_scaled_sales(data_feat)
        data_feat["Sales"].isna().any().sum()
        SIZE = len(data_agg["Sales"])
        
        
        series = scaled_df["scaled_sales"].values[:, np.newaxis]

        ds = tf.data.Dataset.from_tensor_slices(series)
        ds = ds.window(WINDOW_SIZE, shift=1, drop_remainder=True) 
        ds = ds.flat_map(lambda w: w.batch(WINDOW_SIZE))
        ds = ds.batch(SIZE).prefetch(1)
        
        forecast = model.predict(ds)
        Results = list(forecast.reshape(1, forecast.shape[0] * forecast.shape[1])[0].copy())

        Results1 = scaler_obj.inverse_transform(forecast.reshape(-1,1))
        Results1 = list(Results1.reshape(1, Results1.shape[0] * Results1.shape[1])[0])
        
    

        
        return  Results1, Results
        
    except KeyError:
        print("Sales Data is expeceted to have Sales and Date columns")
        return False
        
        

def forcast_next_sales(model, sales, daysToForcast=1):
    forcasts = []
    scaled_forcasts = []
    dates = []
    
    new_sales_df = sales.copy()
    while len(forcasts) < daysToForcast:
        forcast, scaled_forcast = forcast_next_one_sale(model1, new_sales_df)
        forcasts += forcast
        
        scaled_forcasts += scaled_forcast
        size=len(new_sales_df["Sales"])
        
        truncated_sales = new_sales_df.tail(size - len(scaled_forcast))
                
        new_sales = truncated_sales['Sales'].to_list() + scaled_forcast
        next_dates = []
        
        for i in range(len(scaled_forcast)):
            next_date = new_sales_df["Date"].to_list()[-1] + datetime.timedelta(days=1)
            next_dates.append(next_date)     
        
        new_dates = truncated_sales['Date'].to_list() + next_dates
        new_sales_df = pd.DataFrame()
        new_sales_df["Date"] = new_dates
        new_sales_df["Sales"] = new_sales
    
    res_df = pd.DataFrame()
    res_df["Date"] = new_dates
    res_df["forcasts"] = forcasts
    
    return res_df

# %%
data_agg["Date"] = data_agg.index
data_agg["Date"] = data_agg["Date"].astype("datetime64")
res_df = forcast_next_sales(model1, data_agg.head(49), 49)
res_df
# Out:
#          Date     forcasts
# 0  2013-02-19  8154.290039
# 1  2013-02-20  4604.961914
# 2  2013-02-21  3254.734131
# 3  2013-02-22  2210.645264
# 4  2013-02-23  1407.121582
# 5  2013-02-24  1432.688232
# 6  2013-02-25  3064.864990
# 7  2013-02-26  4843.985352
# 8  2013-02-27  4811.833984
# 9  2013-02-28  4086.833008
# 10 2013-03-01  2858.383789
# 11 2013-03-02  1802.192017
# 12 2013-03-03  1297.086304
# 13 2013-03-04  1175.364380
# 14 2013-03-05  1253.996216
# 15 2013-03-06  1392.858398
# 16 2013-03-07  1541.564087
# 17 2013-03-08  1709.252197
# 18 2013-03-09  1933.646240
# 19 2013-03-10  2248.372070
# 20 2013-03-11  2637.689697
# 21 2013-03-12  3043.080811
# 22 2013-03-13  3345.002686
# 23 2013-03-14  3395.118896
# 24 2013-03-15  3161.937012
# 25 2013-03-16  2772.427734
# 26 2013-03-17  2398.588623
# 27 2013-03-18  2120.785156
# 28 2013-03-19  1956.079346
# 29 2013-03-20  1872.907471
# 30 2013-03-21  1834.964478
# 31 2013-03-22  1814.168823
# 32 2013-03-23  1796.565430
# 33 2013-03-24  1771.965332
# 34 2013-03-25  1722.202271
# 35 2013-03-26  1640.872559
# 36 2013-03-27  1543.018799
# 37 2013-03-28  1440.241821
# 38 2013-03-29  1336.687622
# 39 2013-03-30  1223.365601
# 40 2013-03-31  1118.060547
# 41 2013-04-01   986.046448
# 42 2013-04-02   888.909485
# 43 2013-04-03   806.390381
# 44 2013-04-04   742.270386
# 45 2013-04-05   701.865906
# 46 2013-04-06   682.905945
# 47 2013-04-07   681.165283
# 48 2013-04-08   707.994812

# %%
model1.save("../models/lstm_sales_pred_model.h5")
